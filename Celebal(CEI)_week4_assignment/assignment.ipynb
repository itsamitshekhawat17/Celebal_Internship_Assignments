# %% [markdown]
# # Celebal Technologies – Week 4 Assignment
#
# # Azure Cloud Fundamentals and Data Pipeline Implementation using Azure Data Factory
#
# ## Submitted By:
# ### Amit Singh

# %% [markdown]
# ## Objective
#
# The objective of this assignment is to understand Azure cloud concepts and build an end-to-end data pipeline using Azure Storage Account and Azure Data Factory (ADF).

# %% [markdown]
# # Step 1 – Creating Resource Group
#
# A Resource Group named **amit_celebal_rg** was created in Microsoft Azure.

# %%
from IPython.display import Image
Image(filename='screenshots/1_resource_group.png')

# %% [markdown]
# # Step 2 – Creating Azure Storage Account
#
# An Azure Storage Account named **amitcelebalstorage** was created.

# %%
Image(filename='screenshots/2_storage_account.png')

# %% [markdown]
# # Step 3 – Creating Blob Containers
#
# Two Blob Containers were created inside the Storage Account:
#
# - **source** → Stores source CSV file
# - **destination** → Stores copied output file

# %%
Image(filename='screenshots/3_source_and_destination.png')

# %% [markdown]
# # Step 4 – Uploading CSV Dataset
#
# The Superstore CSV dataset was uploaded into the **source** Blob Container.
#
# Dataset used:
# - Superstore.csv
#
#
# ```

# %%
Image(filename='screenshots/4_superstore_dataset.png')

# %% [markdown]
# # Step 5 – Creating Azure Data Factory
#
# An Azure Data Factory instance named **amit-adf-pipeline** was created.
#
# Azure Data Factory is a cloud-based ETL and data integration service used to:

# %%
Image(filename='screenshots/5_adf(creation).png')

# %% [markdown]
# # Step 6 – Overview of Resource Group
#
# The Resource Group overview shows all Azure resources created for this assignment.
#
# The following resources were successfully created:
# - Azure Storage Account → amitcelebalstorage
# - Azure Data Factory → amit-adf-pipeline

# %%
Image(filename='screenshots/5_resource_group_overview.png')

# %% [markdown]
# # Step 7 – Exploring Azure Data Factory UI
#
# The Azure Data Factory Studio interface was explored.
#
# Main sections studied:
# - Author → Create pipelines and datasets
# - Monitor → Monitor pipeline execution
# - Manage → Create Linked Services

# %%
Image(filename='screenshots/6_adf_ui.png')

# %% [markdown]
# # Step 8 – Creating Linked Service
#
# A Linked Service was created to establish a connection between Azure Data Factory and Azure Blob Storage.
#
# Configuration used:
# - Name = amit_adf_linked_service
# - Azure Blob Storage connector
# - Account Key Authentication
# - Storage Account: amitcelebalstorage
#
# ```

# %%
Image(filename='screenshots/7_linked_service.png')

# %% [markdown]
# # Step 9 – Creating Source and Destination Datasets
#
# Datasets were created to represent the source and destination files.
#
# ### Source Dataset
# - Connected to source container
# - Points to Superstore.csv
#
# ### Destination Dataset
# - Connected to destination container

# %%
Image(filename='screenshots/8_datasets.png')

# %% [markdown]
# # Step 10 – Using Get Metadata Activity
#
# The Get Metadata activity was added to retrieve information about the source CSV file.

# %%
Image(filename='screenshots/9_get_metadata.png')

# %% [markdown]
# # Step 11 – Creating Copy Data Pipeline
#
# A Copy Data activity was added to the pipeline to transfer the CSV file from source container to destination container.
#
# Pipeline Flow:
#
# Get Metadata → Copy Data
# ### Source:
# - source/Superstore.csv
#
# ### Destination:
# - destination container

# %%
Image(filename='screenshots/10_copy_data(creation).png')

# %% [markdown]
# # Step 12 – Executing Pipeline
#
# The pipeline was executed using the Debug option in Azure Data Factory.
#
# After successful execution:
# - Pipeline status turned green
# - File transfer completed successfully
# - Output file appeared in destination container

# %%
Image(filename='screenshots/11_pipeline_success.png')

# %% [markdown]
# # Step 13 – Verifying Copied File
#
# The copied CSV file was verified inside the destination Blob Container.
#
# This confirmed that the end-to-end pipeline executed successfully.

# %%
Image(filename='screenshots/12_copy_to_destination.png')

# %% [markdown]
# # Step 14 – Monitoring Pipeline Execution
#
# Pipeline execution was monitored using the Monitor section in Azure Data Factory.
#
# The Monitor dashboard displayed:
# - Execution status
# - Activity runtime
# - Success logs
# - Pipeline duration

# %%
Image(filename='screenshots/13_moniter_pipeline.png')

# %% [markdown]
# # Step 15 – Assigning IAM Roles
#
# IAM (Identity and Access Management) roles were configured to provide secure access between Azure Data Factory and Azure Storage Account.

# %%
Image(filename='screenshots/14_assigning_IMA_roles.png')

# %% [markdown]
# # Step 16 - For each activity(optional)
# The ForEach activity was added after the Get Metadata activity.
#
# Pipeline Flow:
#
# Get Metadata → ForEach
#
# Inside the ForEach activity:
# -       If True :
# -           Copy Data activity was executed for each file

# %%
Image(filename='screenshots/15_for_each_activity1.png')

# %% [markdown]
# # Key Insights
#
# - Azure Storage Account was used to store both source and destination datasets.
#
# - Blob Containers provided scalable cloud-based storage for CSV files.
#
# - Azure Data Factory successfully connected to Blob Storage using Linked Services.
#
# - Get Metadata activity retrieved file information before data movement.
#
# - Copy Data activity successfully transferred the CSV file from source to destination container.
#
# - IAM roles ensured secure communication and controlled access between Azure services.
#
# - The project demonstrated a complete end-to-end ETL pipeline using Azure cloud services.

# %% [markdown]
# # Technologies Used
#
# - Microsoft Azure
# - Azure Storage Account
# - Azure Blob Storage
# - Azure Data Factory
# - Azure IAM
# - CSV Dataset
